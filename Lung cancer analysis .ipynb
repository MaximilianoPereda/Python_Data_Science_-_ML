# %% [markdown]
# ***Welcome to the kaggle smoker dataset.
# In this dataset we will analyze the data on which gender is the one who smokes the most, the race who smokes the most,
# with the average age for a smoker in the dataset.***

# %% [markdown]
# ***first i import the libraries i belive i will be using.***

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# this code is to import the csv dataset into pandas and explore a little

# %%
df = pd.read_csv('lung_cancer.csv')
df.head(10)
# Out:
#        id  age  gender   race   smoker  days_to_cancer stage_of_cancer
# 0  100001   70    Male  White  Current             NaN             NaN
# 1  100002   66    Male  White  Current             NaN             NaN
# 2  100003   64    Male  White  Current             NaN             NaN
# 3  100004   60    Male  White   Former             NaN             NaN
# 4  100005   64    Male  White   Former             NaN             NaN
# 5  100006   56  Female  White  Current             NaN             NaN
# 6  100007   69    Male  White  Current             NaN             NaN
# 7  100008   56  Female  White  Current             NaN             NaN
# 8  100009   55    Male  White  Current             NaN             NaN
# 9  100010   68    Male  White   Former             NaN             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53427 entries, 0 to 53426
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               53427 non-null  int64
#  1   age              53427 non-null  int64
#  2   gender           53427 non-null  object
#  3   race             53166 non-null  object
#  4   smoker           53427 non-null  object
#  5   days_to_cancer   2033 non-null   float64
#  6   stage_of_cancer  2032 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.9+ MB

# %%
sns.pairplot(df)

# %% [markdown]
# ***this is where we will be analyzing the dataset.
# the next countplot is comparing genders from current and former smokers.***

# %%
sns.countplot(data=df, x=df['gender'] , hue = df['smoker'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# ***the next code is a comparison of race swith the amounts of smokers per race. as you can see the race with
# the most amount of smokers is the White race. ***

# %%
sns.countplot(data=df, x= 'race')
plt.figure(figsize=(50, 4))

# %%
sns.histplot(data=df,x='age',hue='race')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
the next two codes are the youngest smoker and the oldest smoker. 
the youngest is 43.
the oldest is 79.

# %%
df['age'].min()
# Out:
# 43

# %%
df['age'].max()
# Out:
# 79

# %%
df['age'].mean()
# Out:
# 61.4174481067625

# %% [markdown]
# ***the average age for smokers is 61.
# after a quick analysis on this dataset we can determin that the most smokers are white male men with aproximatly 48,000 smokers
# whereas the other races only a few hundred smoke.***
