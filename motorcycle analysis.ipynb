# %% [markdown]
# ***welcome, we will be analyzing a kaggle dataset on motorcycles sold. The dataset consists of name, selling price, year, seller type, owner, KM driven and ex_showroom_price.
# some of the analysis performed was a corralation between the collumns and finding trends.
# First I will import the libraries nessary for the data analysis such as pandas, numpy, seaborn, and matplotlib.***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# *** we will then explore the dataset and check the header, information and details.***

# %%
df = pd.read_csv('BIKE DETAILS.csv')
df.head()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.1+ KB

# %%
df.describe()
# Out:
#        selling_price         year      km_driven  ex_showroom_price
# count    1061.000000  1061.000000    1061.000000       6.260000e+02
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       7.749659e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     70000.000000  2017.000000   43000.000000       8.703150e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %% [markdown]
# *** the next codes are figuring out a trend on the dataset and it appears that most of the bike owners are for the first owner at over 900.
# the years 2017 and 2018 are the years with the most bike sales. I assume the reason 2019 is not on the top is because the 2019 owners do not want to get rif of the bike yet, following the trend the following year will be when the 2019 owners will start selling and will be on top with 2017 and 2018.***

# %%
df['owner'].value_counts().head()
# Out:
# 1st owner    924
# 2nd owner    123
# 3rd owner     11
# 4th owner      3
# Name: owner, dtype: int64

# %%
df["year"].value_counts()
# Out:
# 2017    133
# 2018    131
# 2016    107
# 2015    100
# 2014     91
# 2019     86
# 2013     73
# 2012     70
# 2011     61
# 2010     60
# 2007     29
# 2008     28
# 2009     28
# 2006     20
# 2005     14
# 2000      6
# 2004      5
# 2002      3
# 2020      3
# 1998      3
# 1997      2
# 2001      2
# 1988      1
# 1999      1
# 1991      1
# 2003      1
# 1993      1
# 1995      1
# Name: year, dtype: int64

# %%
df["name"].value_counts().head(10)
# Out:
# Bajaj Pulsar 150                 41
# Royal Enfield Classic 350        27
# Honda Activa [2000-2015]         23
# Honda CB Hornet 160R             22
# Bajaj Pulsar 180                 20
# Royal Enfield Thunderbird 350    19
# Hero Honda Splendor Plus         17
# Bajaj Discover 125               16
# Yamaha FZ S V 2.0                16
# Honda Activa 3G                  15
# Name: name, dtype: int64

# %% [markdown]
# ***Visualization***
# ***,,,I did not compare dealer with individual sellers because the dealer hue is very small compared to individual for this dataset.
# we will be focusing on coorallation between number of owners, price, and KM_driven.***

# %%
sns.pairplot(df, hue = 'owner')

# %%
sns.scatterplot(data = df, x = 'year', y = 'selling_price', hue='owner')
# Out:
# <AxesSubplot:xlabel='year', ylabel='selling_price'>

# %%
sns.scatterplot(data = df, x = 'km_driven', y = 'selling_price', hue = 'owner', palette = 'rocket')
plt.figure(figsize=(50, 4))

# %%
sns.scatterplot(data = df, y = 'year', x = 'km_driven', hue= 'owner')
plt.figure(figsize=(50, 4))

# %%
sns.countplot(data=df,x='seller_type')
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='count'>

# %%
sns.boxplot(data = df, x= 'owner', y='km_driven')
# Out:
# <AxesSubplot:xlabel='owner', ylabel='km_driven'>
